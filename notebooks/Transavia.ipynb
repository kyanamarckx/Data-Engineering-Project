# %% [markdown]
# add imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../csv/Transavia.csv")

# %%
df.describe()
# Out:
#        Departure Destination        Date Departure time Arrival time  \
# count       2013        2013        2013           2013         2013
# unique         1          11         183             33           36
# top     Brussels       Corfu  01/04/2023           None         None
# freq        2013         183          11           1473         1473
#
#        Flightnumber Duration Price
# count          2013     2013  2013
# unique           16        8    98
# top            None     None  None
# freq           1473     1473  1473

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013 entries, 0 to 2012
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Departure       2013 non-null   object
#  1   Destination     2013 non-null   object
#  2   Date            2013 non-null   object
#  3   Departure time  2013 non-null   object
#  4   Arrival time    2013 non-null   object
#  5   Flightnumber    2013 non-null   object
#  6   Duration        2013 non-null   object
#  7   Price           2013 non-null   object
# dtypes: object(8)
# memory usage: 125.9+ KB

# %%
df.filter(items=["Departure", "Destination", "Date", "Departure time", "Arrival time", "Flightnumber", "Duration", "Price"])
# Out:
#      Departure Destination        Date Departure time Arrival time  \
# 0     Brussels       Corfu  01/04/2023           None         None
# 1     Brussels       Corfu  02/04/2023           None         None
# 2     Brussels       Corfu  03/04/2023           None         None
# 3     Brussels       Corfu  04/04/2023           None         None
# 4     Brussels       Corfu  05/04/2023           None         None
# ...        ...         ...         ...            ...          ...
# 2008  Brussels    Tenerife  26/09/2023           None         None
# 2009  Brussels    Tenerife  27/09/2023          06:30        10:00
# 2010  Brussels    Tenerife  28/09/2023           None         None
# 2011  Brussels    Tenerife  29/09/2023           None         None
# 2012  Brussels    Tenerife  30/09/2023          06:30        10:00
#
#      Flightnumber Duration  Price
# 0            None     None   None
# 1            None     None   None
# 2            None     None   None
# ...

# %%
df["Departure"].value_counts()
# Out:
# Brussels    2013
# Name: Departure, dtype: int64

# %%
df["Destination"].value_counts()
# Out:
# Corfu       183
# Kreta       183
# Rhodos      183
# Brindisi    183
# Napels      183
# Palermo     183
# Faro        183
# Alicante    183
# Ibiza       183
# Malaga      183
# Tenerife    183
# Name: Destination, dtype: int64

# %%
df["Date"].value_counts()
# Out:
# 01/04/2023    11
# 25/07/2023    11
# 27/07/2023    11
# 28/07/2023    11
# 29/07/2023    11
#               ..
# 03/06/2023    11
# 04/06/2023    11
# 05/06/2023    11
# 06/06/2023    11
# 30/09/2023    11
# Name: Date, Length: 183, dtype: int64

# %%
df["Departure time"].value_counts()
# Out:
# None     1473
# 06:30      62
# 07:15      38
# 06:35      36
# 07:10      35
# 17:25      35
# 07:30      32
# 17:05      31
# 16:45      27
# 16:20      23
# 16:05      18
# 15:40      18
# 15:55      17
# 06:50      17
# 16:50      14
# 12:30      13
# 17:20      12
# 16:00       9
# 15:30       9
# 07:00       9
# 18:40       9
# 16:30       9
# 07:40       9
# 16:10       8
# 18:25       8
# 15:35       8
# 07:20       8
# 17:40       5
# 15:25       5
# 16:15       5
# 07:25       4
# 15:20       4
# 16:35       3
# Name: Departure time, dtype: int64

# %%
df["Arrival time"].value_counts()
# Out:
# None     1473
# 19:55      57
# 08:55      44
# 09:05      31
# 11:00      27
# 09:10      25
# 09:15      25
# 18:40      25
# 18:50      24
# 10:00      18
# 17:35      18
# 18:35      18
# 19:00      18
# 18:45      16
# 09:25      14
# 19:15      14
# 14:50      13
# 10:20      13
# 11:40      13
# 11:35      13
# 19:45      12
# 10:30       9
# 17:55       9
# 09:35       9
# 21:05       9
# 20:20       9
# 20:50       8
# 18:00       8
# 19:05       8
# 19:35       8
# 20:05       5
# 18:15       5
# 09:55       5
# 18:10       4
# 09:20       4
# 19:10       2
# Name: Arrival time, dtype: int64

# %%
df["Flightnumber"].value_counts()
# Out:
# None      1473
# HV9007     109
# HV9003      97
# HV9009      91
# HV9033      61
# HV9211      35
# HV9209      27
# HV9061      27
# HV9121      24
# HV9005      16
# HV9031      13
# HV9011       9
# HV9015       9
# HV9023       9
# HV9021       8
# HV9013       5
# Name: Flightnumber, dtype: int64

# %%
df["Duration"].value_counts()
# Out:
# None    1473
# 145      141
# 115      126
# 150       97
# 170       74
# 265       62
# 210       27
# 140       13
# Name: Duration, dtype: int64

# %%
df["Price"].value_counts()
# Out:
# None     1473
# 97.0       21
# 112.0      21
# 87.0       19
# 167.0      19
#          ...
# 249.0       1
# 105.0       1
# 321.0       1
# 202.0       1
# 154.0       1
# Name: Price, Length: 98, dtype: int64

# %%
BAAV = df[(df["Destination"] == "Alicante") & (df["Date"].str.contains("/05/2023"))]
BAAV
# Out:
#      Departure Destination        Date Departure time Arrival time  \
# 1311  Brussels    Alicante  01/05/2023           None         None
# 1312  Brussels    Alicante  02/05/2023          17:25        19:55
# 1313  Brussels    Alicante  03/05/2023          16:05        18:35
# 1314  Brussels    Alicante  04/05/2023          06:50        09:15
# 1315  Brussels    Alicante  05/05/2023           None         None
# 1316  Brussels    Alicante  06/05/2023          16:20        18:50
# 1317  Brussels    Alicante  07/05/2023          17:25        19:55
# 1318  Brussels    Alicante  08/05/2023           None         None
# 1319  Brussels    Alicante  09/05/2023          17:25        19:55
# 1320  Brussels    Alicante  10/05/2023          16:05        18:35
# 1321  Brussels    Alicante  11/05/2023          06:50        09:15
# 1322  Brussels    Alicante  12/05/2023           None         None
# 1323  Brussels    Alicante  13/05/2023          16:20        18:50
# ...

# %%
faro = df[(df["Destination"] == "Faro") & (df["Date"].str.contains("/06/2023")) & (df["Price"] != str(None))]
farogem = faro["Price"].astype(float).mean()
farogem
# Out:
# 105.5

# %%
ibiza = df[(df["Destination"] == "Ibiza") & (df["Departure time"]) & (df["Date"].str.contains("24/05/2023"))]
ibiza
# Out:
#      Departure Destination        Date Departure time Arrival time  \
# 1517  Brussels       Ibiza  24/05/2023          06:30        08:55
#
#      Flightnumber Duration  Price
# 1517       HV9009      145  182.0

# %%
TNF = df[(df["Destination"] == "Tenerife") & (df["Arrival time"]) & (df["Date"].str.contains("29/07/2023"))]
TNF
# Out:
#      Departure Destination        Date Departure time Arrival time  \
# 1949  Brussels    Tenerife  29/07/2023          07:00        10:30
#
#      Flightnumber Duration  Price
# 1949       HV9061      210  257.0

# %%
Kreta = df[(df["Destination"] == "Kreta") & (df["Date"].str.contains("/08/2023"))]
Kreta
# Out:
#     Departure Destination        Date Departure time Arrival time  \
# 305  Brussels       Kreta  01/08/2023          07:15        11:40
# 306  Brussels       Kreta  02/08/2023           None         None
# 307  Brussels       Kreta  03/08/2023          15:55        20:20
# 308  Brussels       Kreta  04/08/2023           None         None
# 309  Brussels       Kreta  05/08/2023          06:35        11:00
# 310  Brussels       Kreta  06/08/2023           None         None
# 311  Brussels       Kreta  07/08/2023           None         None
# 312  Brussels       Kreta  08/08/2023          07:15        11:40
# 313  Brussels       Kreta  09/08/2023           None         None
# 314  Brussels       Kreta  10/08/2023          15:55        20:20
# 315  Brussels       Kreta  11/08/2023           None         None
# 316  Brussels       Kreta  12/08/2023          06:35        11:00
# 317  Brussels       Kreta  13/08/2023           None         None
# ...
